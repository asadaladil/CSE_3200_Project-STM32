# %%
for i in range(10):
    with open(f"./Digit_Image_Array/Digit{i}.txt",mode="r") as file:
        file=file.readlines()
        print(i,'-',len(file)//29)
# Out:
# 0 - 7000
# 1 - 7000
# 2 - 7000
# 3 - 7000
# 4 - 7000
# 5 - 7000
# 6 - 7000
# 7 - 7000
# 8 - 7000
# 9 - 6900

# %%
# import tensorflow as tf
# from keras import layers, models
# import numpy as np

# MODEL_PATH="Trained_digit_model.h5"
# (X, Y),(x, y)=tf.keras.datasets.mnist.load_data() # 60000 train image, 10000 test image
# model=tf.keras.models.load_model(MODEL_PATH)
# cnt=0
# for i in range(20,30):
#     input_data=x[i]
#     if np.max(input_data)>1.0:
#         input_data=input_data.astype('float32')/255.0
#     else:
#         input_data=input_data.astype('float32')

#     input_data=input_data.reshape(1, 28, 28, 1) #[Batch Size, Height, Width, Channels]

#     predictions=model.predict(input_data)
#     predicted_digit=np.argmax(predictions)
#     if predicted_digit==y[i]:
#         cnt+=1

# print(f"{cnt}/{len(y)}")
